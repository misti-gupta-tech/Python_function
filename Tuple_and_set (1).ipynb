# %% [markdown]
# # Tuple
# ## ordered collection of items
# ## symbol ()
# ## Tuple Immutable
# ## supperts index

# %%
# create a tuple
students=(101,"chirag",'CSE',8.9)
print(students)
# Out:
# (101, 'chirag', 'CSE', 8.9)

# %%
# create a tuple
students=(101,"chirag",'CSE',8.9)
print(students)

# access by index
print(students[2])
# Out:
# (101, 'chirag', 'CSE', 8.9)
# CSE

# %%
# create a tuple
students=(101,"chirag",'CSE',8.9)
print(students)

print("Access by negative index :CSE",students[-2] )
# Out:
# (101, 'chirag', 'CSE', 8.9)
# Access by negative index :CSE CSE

# %%
subjects =("Dsv",'machine Learning ', 'OS', 'Cloud', 'SQl','Statistics','Python')
print(subjects)

# find the length of the tuple
print ("Length of the tuple:",len(subjects))
# Out:
# ('Dsv', 'machine Learning ', 'OS', 'Cloud', 'SQl', 'Statistics', 'Python')
# Length of the tuple: 7

# %%
# Tuple slicing

print(subjects[3:])
print(subjects[1:5])
# Out:
# ('Cloud', 'SQl', 'Statistics', 'Python')
# ('machine Learning ', 'OS', 'Cloud', 'SQl')

# %%
# tuple is mutable or immutable
print(students)
# Deletion and Updation data
students[1]="Manish"
print(students)
# Out:
# (101, 'chirag', 'CSE', 8.9)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1375/387956909.py in <cell line: 0>()
#       2 print(students)
#       3 # Deletion and Updation data
# ----> 4 students[1]="Manish"
#       5 print(students)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Nested tuple
student_info=(1005,'Rahul',(89,98,78,75))
print (student_info)
print ("Nested tuple displaying 3rd subject mark:",student_info[2][2])
# Out:
# (1005, 'Rahul', (89, 98, 78, 75))
# Nested tuple displaying 3rd subject mark: 78

# %%
# showing positon
position =student_info.index("Rahul")
print("Data Rahul present in the index ",position)
# Out:
# Data Rahul present in the index  1

# %% [markdown]
# # SET
# ## unordered collections of items
# ##  mutable
# ## symbol {}
# ## No duplications
# ## it will give the unique values
# ## union, intersection ,difference, symmetric difference, superset

# %%
# create a set
subjects_info={'Data Science and Visualisation ','SQL', 'Statistics','Machine Learning'}
print(subjects_info)
# Out:
# {'Machine Learning', 'Statistics', 'SQL', 'Data Science and Visualisation '}

# %%
students_name={'Amit','Sanjiv','Kalki', 'Amit','Kiran','Neha','Amit','Neha','Sanjiv'}
print(students_name)
# Out:
# {'Sanjiv', 'Kalki', 'Neha', 'Amit', 'Kiran'}

# %%
print(studentsname[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1375/3522708508.py in <cell line: 0>()
# ----> 1 print(studentsname[2])
#
# NameError: name 'studentsname' is not defined

# %%
students_name.add('Priya')
print(students_name)
# update the set
students_name.update(['Anil','Nandini','Balaji'])
print(students_name)
# Out:
# {'Sanjiv', 'Kalki', 'Priya', 'Neha', 'Amit', 'Kiran'}
# {'Neha', 'Nandini', 'Sanjiv', 'Kalki', 'Anil', 'Balaji', 'Amit', 'Kiran', 'Priya'}

# %%
# remove an item in the set
#students_name.remove('Amit')
#print(students_name)


# remove an item
#students_name.remove ('Amit ')
#print(students_name)

# students
students_name.discard('Priya')
print(students_name)


students_name.discard("Amit")
print(students_name)
# Out:
# {'Neha', 'Nandini', 'Sanjiv', 'Kalki', 'Anil', 'Balaji', 'Kiran'}
# {'Neha', 'Nandini', 'Sanjiv', 'Kalki', 'Anil', 'Balaji', 'Kiran'}

# %%
# clear and delete
numbers ={89,78,68,97,69}
numbers.clear()
print(numbers)
# Out:
# set()

# %%
#delete
del numbers
print(numbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1375/594372324.py in <cell line: 0>()
#       1 #delete
# ----> 2 del numbers
#       3 print(numbers)
#
# NameError: name 'numbers' is not defined

# %%
# find the element in the set
print('Anil' in students_name)
# Out:
# True

# %%
# set operations
# uions
# Intersection
# difference
# symetric difference

python_students={'Rahul','Priya',"Hari",'Ganesh'}
java_students={'Rahul','Hari','Kiran','Ravi','Giri'}
res_union =python_students.union(java_students)
print(res_union)
# Out:
# {'Ravi', 'Ganesh', 'Kiran', 'Giri', 'Priya', 'Rahul', 'Hari'}

# %%
# Intersection
res_inter=python_students.intersection(java_students)
print(res_inter)
# Out:
# {'Rahul', 'Hari'}

# %%
# difference
res_diff=python_students.difference(java_students)
print(res_diff)
# Out:
# {'Priya', 'Ganesh'}

# %%
lst=[101,102,103,104,101,106,102,103]
unique_rollno =set(lst)
print(unique_rollno)
unique_lst_rollno=list(unique_rollno)
print(unique_lst_rollno)
# Out:
# {101, 102, 103, 104, 106}
# [101, 102, 103, 104, 106]
